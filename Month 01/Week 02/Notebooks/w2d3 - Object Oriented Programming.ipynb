# %% [markdown]
# # Spring of Code - Artificial Intelligence
# ## Week 02: Object Oriented Programming
# ### Day 03: Classes & Objects, and Inheritance
# In this notebook, we will learn about **Object Oriented Programming (OOP)** in Python.

# %% [markdown]
# # Object Oriented Programming (OOP)
# Object Oriented Programming (OOP) is a programming paradigm.
# - It uses "objects" to represent data and methods to manipulate that data.
# - It helps in organizing code, making it reusable, and easier to maintain.
# - OOP is based on four main principles: Encapsulation, Abstraction, Inheritance, and Polymorphism.

# %% [markdown]
# ## Classes and Objects
# - A class is a blueprint for creating objects. It defines attributes (data) and methods (functions) that the objects created from the class will have.
# - An object is an instance of a class. It contains data and can perform actions defined by the class.
#
# In Python, you can define a class using the `class` keyword. Here's an example:
#
# ```python
# class ClassName:
#     # Constructor method to initialize attributes
#     def __init__(self, attribute1, attribute2):
#         self.attribute1 = attribute1  # Attribute
#         self.attribute2 = attribute2    # Attribute
#
#     # Method of the class (functions inside a class are called methods)
#     def method1(self):
#       pass
#
#     def method2(self, param):
#         pass
# ```

# %%
class Person:
    # properties/data => attributes
    def __init__(self,name, age): # Constructor
        self.name = name
        age = age
        print("Constructor is called")
        # other attributes

    # behaviour/functions => methods
    def walk(self):
        print(f"{self.name} is walking")
        print(self)

    # other behaviours

# %%
p = Person("Ahmad", 30)
# Out:
# Constructor is called

# %%
p.name
p.age
# Out:
# 30

# %%
p3 = Person("Ahmad", 30)
p2 = Person("Ali", 25)
p2.name
# Out:
# Constructor is called
# Constructor is called
# 'Ali'

# %%
# Person.walk(p3)
p2.walk() # Person.walk(p2)
# Out:
# Ali is walking
# ...

# %%
print(Person)
# Out:
# <class '__main__.Person'>

# %%
p = Person("Alice", 15)
# Out:
# Constructor is called

# %%
p.name
# Out:
# 'Alice'

# %%
p.age
# Out:
# 15

# %%
p.walk() # Person.walk(p)
# Out:
# Alice is walking
# ...

# %%
Person.walk(p)
# Out:
# Alice is walking
# ...

# %%
p2 = Person("Ali", 12)
# Out:
# Constructor is called

# %%
p2.walk()
p2.name = 'Ahmad'
p2.walk()
# Out:
# Ahmad is walking
# ...
# Ahmad is walking
# ...

# %%
# Object initialization
person1 = Person("Ahmad", 25) # Creating Object, __init__ Constructor is called automatically
print(person1)
# Out:
# Constructor is called
# ...

# %%
person1.walk()
# Out:
# Ahmad is walking
# ...

# %%
person2 = Person("Qasim", 30)
print(person2.name)
print(person2.age)

# %% [markdown]
# ## Instance Variables and Methods
#
# - Instance variables are attributes that belong to an instance (object) of a class.
# - They are defined in the constructor method `__init__`.
# - Instance methods are functions that operate on the instance of the class.
# - They can access and modify instance variables.
#
# Here's an example of a class with instance variables and methods:
#
# ```python
# class BankAccount:
#     def __init__(self, account_holder, balance=0):
#         self.account_holder = account_holder  # Instance variable
#         self.balance = balance  # Instance variable
#
#     def deposit(self, amount):  # Instance method
#         pass
#
#     def withdraw(self, amount):  # Instance method
#         pass
#
#     def get_balance(self):  # Instance method
#         pass
# ```

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        
    def withdraw(self, amount):
        if self.balance < amount:
            print("Not enough blance")
            return
        self.balance -= amount
    
    def get_balance(self):
        print(f"You current account balance is {self.balance}")
    
    def check_self(self):
        print(self)

# %%
my_account = BankAccount(account_holder="Ahmad", balance=1000)
my_account.account_holder
# Out:
# 'Ahmad'

# %%
my_account.deposit(10000)
my_account.get_balance()
# Out:
# You current account balance is 11000

# %%
my_account.withdraw(50000)
# Out:
# Not enough blance

# %%
print(my_account)

# %%
my_account.check_self()

# %% [markdown]
# ## Class Variables and Functions
# - Class variables are shared among all instances of a class.
# - They are defined within the class but outside any methods.
# - Class methods are methods that operate on the class itself rather than on instances of the class.
# - They are defined using the `@classmethod` decorator and take `cls` as the first parameter.
#
# Here's an example of a class with class variables and class methods:
#
# ```python
# class ClassName:
#     class_var = None  # Class variable
#
#     def __init__(self, params):
#         # Attributes or instance variables
#         pass
#
#
#     @classmethod
#     def class_method(cls):  # Class functions
#         pass
# ```

# %%
class Player:
    player_count = 0 # class

    def __init__(self, name):
        self.name = name
        Player.player_count += 1

    def die(self):
        pass

# %%
p1 = Player("Ali")

# %%
p1.player_count
# Out:
# 1

# %%
p2 = Player("Waqas")
p3 = Player("Usman")

# %%
p1.player_count
# Out:
# 3

# %%
Player.player_count
# Out:
# 3

# %% [markdown]
# #### Some practical examples

# %% [markdown]
# #### 1. Online Shopping Cart

# %%
class ShoppingCart:
    tax_rate = 0.05

    def __init__(self):
        self.total = 0

    def add_item(self, price):
        if not self.is_price_valid(price):
            print("Invalid price")
            return
        self.total += price

    def final_amount(self):
        return self.total + (self.total * ShoppingCart.tax_rate)

    @classmethod
    def change_tax(cls, new_tax):
        cls.tax_rate = new_tax

    @staticmethod
    def is_price_valid(price):
        return price > 0

# %%
cart = ShoppingCart()

# %%
cart.add_item(200)

# %%
cart.final_amount()
# Out:
# 210.0

# %%
cart2 = ShoppingCart()
cart2.add_item(0)
ShoppingCart.change_tax(0.1)
# Out:
# Invalid price

# %%
cart.final_amount()
# Out:
# 220.0

# %% [markdown]
# #### 2. Library Book System

# %%
class Book:
    total_books = 0

    def __init__(self, title):
        if not self.is_valid_title(title):
            print("Invalid title")
            return
        self.title = title
        Book.total_books += 1 # Book.total_books = Book.total_books + 1

    def show_title(self):
        print(self.title)

    @classmethod
    def get_total_books(cls):
        return cls.total_books

    @staticmethod
    def is_valid_title(title):
        return len(title) > 0

# %%
b1 = Book("Python Basics")
b2 = Book("OOP in Python")

print(Book.get_total_books())
# Out:
# 2

# %%
b3 = Book("")
b3.title
# Out:
# Invalid title
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 b3 = Book("")
# ----> 2 b3.title
#
# AttributeError: 'Book' object has no attribute 'title'

# %% [markdown]
# #### 3. Employee Management System

# %%
class Employee:
    company = "Tech Corp"

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def yearly_salary(self):
        return self.salary * 12

    @classmethod
    def update_company(cls, new_name):
        cls.company = new_name

    @staticmethod
    def tax(salary):
        return salary * 0.1

# %%
e1 = Employee("Sara", 50000)

print(e1.yearly_salary())
print(Employee.tax(e1.salary))
# Out:
# 600000
# 5000.0

# %% [markdown]
# #### 4. Bank System

# %%
class BankAccount:
    accounts = []
    bank_name = "Secure Bank"

    def __init__(self, holder, balance):
        if not BankAccount.is_valid_balance(balance):
            raise ValueError("Invalid initial balance")

        self.holder = holder
        self.balance = balance
        BankAccount.accounts.append(self)

    def deposit(self, amount):
        if not BankAccount.is_valid_amount(amount):
            raise ValueError("Invalid deposit amount")
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient funds")
        self.balance -= amount
    def get_balance(self):
        return self.balance

    @classmethod
    def total_bank_balance(cls):
        temp_list = []
        for acc in cls.accounts:
            temp_list.append(acc.balance)
        return sum(temp_list)
        # return sum(acc.balance for acc in cls.accounts)

    @staticmethod
    def is_valid_amount(amount):
        return amount > 0

    @staticmethod
    def is_valid_balance(balance):
        return balance >= 0

# %%
acc1 = BankAccount("Ahmad", 1000)
acc2 = BankAccount("Sara", 2000)

print(BankAccount.total_bank_balance())
# Out:
# 3000

# %%
acc1.deposit(500)
print(acc1.get_balance())
# Out:
# 1500

# %%
BankAccount.total_bank_balance()
# Out:
# 3500

# %%
acc2.get_balance()
BankAccount.total_bank_balance()
# Out:
# 2000

# %% [markdown]
# #### 5. Student Result Analyzer

# %%
class Student:
    students = []

    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
        Student.students.append(self)

    def grade(self):
        if self.marks >= 80:
            return "A"
        elif self.marks >= 60:
            return "B"
        else:
            return "Fail"

    @classmethod
    def class_average(cls):
        return sum(s.marks for s in cls.students) / len(cls.students)

# %%
student1 = Student("Ali", 85)
student2 = Student("Sara", 90)
student3 = Student("Ahmed", 70)

print(Student.class_average())

student1.grade()
(student1.marks + student2.marks + student3.marks) / 3
# Out:
# 81.66666666666667
# 81.66666666666667

# %% [markdown]
# ### Practice Tasks

# %% [markdown]
# 1. Create a Student class
#     - Instance variables: name, marks
#     - Class variable: school_name
#     - Instance method: display student info
#     - Class method: change school name
#     - Static method: check if marks are valid (0–100)
#     <br>
# 2. Create an Employee class
#     - Instance variables: name, salary
#     - Instance method: yearly salary
#     - Static method: tax calculation
#     - Class method: update company name
#     <br>
# 3. Create a BankAccount class
#     - Class variable: list of all accounts
#     - Instance methods: deposit, withdraw
#     - Static method: validate amount
#     - Class method: calculate total money in bank
#     <br>
# 4. Create a MobilePhone class
#     - Instance variables: model, price
#     - Static method: price validation
#     - Class method: apply discount to all phones
#     <br>
# 5. ATM System
#     - Account creation
#     - Deposit / Withdraw
#     - Transaction limit using class variable
#     - Validation using static methods

# %% [markdown]
# 1. Create a Student class
#     - Instance variables: name, marks
#     - Class variable: school_name
#     - Instance method: display student info
#     - Class method: change school name
#     - Static method: check if marks are valid (0–100)

# %%
class Student:
    school_name = 'Corvit'
    def __init__(self, name, marks):
        self.name = name
        if not Student.is_valid_marks(marks):
            raise ValueError("Invalid marks")
        self.marks = marks
        
    def display_info(self):
        print(f"Student Name: {self.name}")
        print(f"Marks: {self.marks}")
        print(f"School: {Student.school_name}")
    
    def update_school(self, new_school):
        Student.school_name = new_school

    @staticmethod
    def is_valid_marks(marks):
        return 0 <= marks <= 100

# %%
print(Student("Ali", 85))
st1 = Student("Ali", 85)
print(st1)

# %%
Student("Ali", 85).display_info()
# Out:
# Student Name: Ali
# Marks: 85
# School: New Corvit

# %%
st1.display_info()
# Out:
# Student Name: Ali
# Marks: 85
# School: New Corvit

# %%
st1.display_info()
# Out:
# Student Name: Ali
# Marks: 85
# School: New Corvit

# %%
st2 = Student("Sara", 90)
st2.display_info()
# Out:
# Student Name: Sara
# Marks: 90
# School: Corvit

# %% [markdown]
# # Inheritance
# Inheritance is a mechanism in OOP that allows a new class (child class) to inherit attributes and methods from an existing class (parent class).
# - This promotes code reusability and establishes a hierarchical relationship between classes.
# - The child class can have its own attributes and methods in addition to those inherited from the parent class.
#
# In Python, inheritance is implemented as follows:
#
# ```python
# class ParentClass:
#     def __init__(self, parent_attr):
#         self.parent_attr = parent_attr
#         print("parent class constructor called")
#
#     def parent_method(self):
#         pass
#
# class ChildClass(ParentClass):  # Inheriting from ParentClass
#     def __init__(self, parent_attr, child_attr):
#         super().__init__(parent_attr)  # Call the constructor of the parent class
#         print("child class constructor called")
#         self.child_attr = child_attr
#
#     def child_method(self):
#         pass
# ```

# %%
class Vehicle:
    def __init__(self, vechicle_type):
        self.vehicle_type = vechicle_type

    def start(self):
        print("Engine started...")

# %%
vehicle = Vehicle("Bus")
vehicle.start()
# Out:
# Engine started...

# %%
class Bus(Vehicle):
    def __init__(self, vehicle_type, make, model, year):
        super().__init__(vehicle_type)
        self.make = make
        self.model = model
        self.year = year
        
    def change_transmission_model(self, mode):
        print(f"Transmission switched to {mode}")

    # Overriding super().start() method
    def start(self):
        # super().start()
        print("Bus engine started")

# %%
bus = Bus("Bus", "Volvo", "abc", 2025)
bus

# %%
bus.start()
# Out:
# Bus engine started

# %%
bus.change_transmission_model("auto")
# Out:
# Transmission switched to auto

# %%
vehicle.start()
# Out:
# Engine started...

# %%
bus.start()
# Out:
# Bus engine started

# %% [markdown]
# #### Some Real World Examples

# %% [markdown]
# #### 1. EMPLOYEE SYSTEM

# %%
class Employee:
    def __init__(self, name, emp_id, salary):
        self.name = name
        self.emp_id = emp_id
        self.salary = salary
    
    def display_info(self):
        print(f"Name: {self.name}, ID: {self.emp_id}")

class Developer(Employee):
    def __init__(self, name, emp_id, salary, programming_language):
        super().__init__(name, emp_id, salary)
        self.programming_language = programming_language
    
    def write_code(self):
        print(f"{self.name} is coding in {self.programming_language}")

class Manager(Employee):
    def __init__(self, name, emp_id, salary, team_size):
        super().__init__(name, emp_id, salary)
        self.team_size = team_size
    
    def conduct_meeting(self):
        print(f"{self.name} is conducting a meeting with {self.team_size} people")

# %%
dev = Developer("Alice", "E001", 80000, "Python")
mgr = Manager("Bob", "E002", 100000, 10)

dev.display_info()  # Inherited
dev.write_code()    # Developer-specific

mgr.display_info()  # Inherited
mgr.conduct_meeting() # Manager-specific
# Out:
# Name: Alice, ID: E001
# Alice is coding in Python
# Name: Bob, ID: E002
# Bob is conducting a meeting with 10 people

# %% [markdown]
# #### 2. BANK ACCOUNT SYSTEM

# %%
class BankAccount:
    def __init__(self, account_no, owner, balance=0):
        self.account_no = account_no
        self.owner = owner
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ${amount}. New balance: ${self.balance}")
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.balance}")

class SavingsAccount(BankAccount):
    def __init__(self, account_no, owner, balance=0, interest_rate=0.05):
        super().__init__(account_no, owner, balance)
        self.interest_rate = interest_rate
    
    def add_interest(self):
        interest = self.balance * self.interest_rate
        self.balance += interest
        print(f"Interest added: ${interest:.2f}")

class CurrentAccount(BankAccount):
    def __init__(self, account_no, owner, balance=0, overdraft_limit=1000):
        super().__init__(account_no, owner, balance)
        self.overdraft_limit = overdraft_limit
    
    def withdraw(self, amount):
        if amount <= self.balance + self.overdraft_limit:
            self.balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.balance}")

# %%
savings = SavingsAccount("SA001", "Alice", 5000, 0.03)
current = CurrentAccount("CA001", "Bob", 1000, 500)

savings.deposit(1000)    # Inherited
savings.add_interest()   # Savings-specific

current.withdraw(1500)   # Overridden (uses overdraft)
# Out:
# Deposited $1000. New balance: $6000
# Interest added: $180.00
# Withdrew $1500. New balance: $-500

# %% [markdown]
# #### 3. BOOK/MEDIA SYSTEM

# %%
class Media:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year
    
    def display_info(self):
        print(f"'{self.title}' by {self.author} ({self.year})")

class Book(Media):
    def __init__(self, title, author, year, pages):
        super().__init__(title, author, year)
        self.pages = pages
    
    def read(self):
        print(f"Reading '{self.title}' - {self.pages} pages")

class Magazine(Media):
    def __init__(self, title, author, year, issue_number):
        super().__init__(title, author, year)
        self.issue_number = issue_number
    
    def flip_pages(self):
        print(f"Flipping through issue #{self.issue_number}")

# %%
book = Book("1984", "George Orwell", 1949, 328)
magazine = Magazine("National Geographic", "Various", 2024, 12)

book.display_info()  # Inherited
book.read()          # Book-specific

magazine.display_info()  # Inherited
magazine.flip_pages()    # Magazine-specific
# Out:
# '1984' by George Orwell (1949)
# Reading '1984' - 328 pages
# 'National Geographic' by Various (2024)
# Flipping through issue #12

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year
    
    def __str__(self):
        return f"'{self.title}' by {self.author} ({self.year})"

book = Book("1984", "George Orwell", 1949)

print(book)  # Calls __str__
# Output: '1984' by George Orwell (1949)

# Without __str__:
# Output: <__main__.Book object at 0x7f8b3c4d5e80>
# Out:
# '1984' by George Orwell (1949)

# %% [markdown]
# ## Dunder Methods/Magic Functions
# Dunder methods (short for "double underscore" methods) are special methods in Python that have double underscores at the beginning and end of their names (e.g., `__init__`, `__str__`, `__repr__`, etc.).
# - They are used to define the behavior of objects for built-in operations and functions.
# - For example, the `__init__` method is called when an object is created, and the `__str__` method defines how an object is represented as a string.

# %%
# Without understanding dunder methods:
num1 = 5
num2 = 3
result = num1 + num2  # How does + work? Magic!
print(result)  # 8

# Behind the scenes:
result = num1.__add__(num2)  # This is what actually happens!
result
# Out:
# 8
# 8

# %% [markdown]
# - Creating an object
#     - obj = MyClass()  # Calls \_\_init\_\_
#
# - Printing an object
#     - print(obj)  # Calls \_\_str\_\_ or \_\_repr\_\_
#
# - Getting length
#     - len(obj)  # Calls \_\_len\_\_
#
# - Adding objects
#     - obj1 + obj2  # Calls \_\_add\_\_

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year
    
    def __str__(self):
        return f"'{self.title}' by {self.author} ({self.year})"

book = Book("1984", "George Orwell", 1949)

print(book)  # Calls __str__
# Output: '1984' by George Orwell (1949)

# Without __str__:
# Output: <__main__.Book object at 0x7f8b3c4d5e80>
# Out:
# '1984' by George Orwell (1949)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __repr__(self):
        return f"Point({self.x}, {self.y})"
    
    def __str__(self):
        return f"({self.x}, {self.y})"

point = Point(3, 4)

print(point)       # Calls __str__: (3, 4)
# print(repr(point)) # Calls __repr__: (3, 4)
point
# Out:
# (3, 4)
# Point(3, 4)

# %%
class Student:
    def __init__(self, name, roll_no, grade):
        self.name = name
        self.roll_no = roll_no
        self.grade = grade
    
    def __str__(self):
        # For end users
        return f"{self.name} (Roll: {self.roll_no}) - Grade: {self.grade}"
    
    def __repr__(self):
        # For developers - can recreate object
        return f"Student('{self.name}', {self.roll_no}, '{self.grade}')"

student = Student("Alice", 101, "A")

print(student)        # Alice (Roll: 101) - Grade: A
student  # Student('Alice', 101, 'A')
# Out:
# Alice (Roll: 101) - Grade: A
# Student('Alice', 101, 'A')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class ComplexNumber:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __str__(self):
        return f"{self.real} + {self.imag}i"

    def __repr__(self):
        return f"{self.real} + {self.imag}i"
    
    def __eq__(self, other):
        if self.real == other.real and self.imag == other.imag:
            return True
        else:
            return False

    def __add__(self, other):
        real = self.real + other.real
        imag = self.imag + other.imag
        
        return ComplexNumber(real, imag)

# %%
obj.display()

# %%
c1 = ComplexNumber(4, 5)
c2 = ComplexNumber(3, 5)
c1 == c2
# Out:
# False

# %%
# __str__
print(c1)
# Out:
# 4 + 5i

# %%
str(c1)
# Out:
# '4 + 5i'

# %%
# __repr__
c1
# Out:
# 4 + 5i

# %%
c2 = ComplexNumber(2, 4)
print(c2)
# Out:
# 2 + 4i

# %%
c1 == c2
# Out:
# False

# %%
c3 = ComplexNumber(2, 4)
c2 == c3
# Out:
# True

# %%
print(c2 + c3)
# Out:
# 4 + 8i

# %%
class Money:
    def __init__(self, amount):
        self.amount = amount
    
    def __add__(self, other):
        if isinstance(other, Money):
            return Money(self.amount + other.amount)
        return NotImplemented
    
    def __sub__(self, other):
        if isinstance(other, Money):
            return Money(self.amount - other.amount)
        return NotImplemented
    
    def __mul__(self, factor):
        # Multiply by number
        if isinstance(factor, (int, float)):
            return Money(self.amount * factor)
        return NotImplemented
    
    def __str__(self):
        return f"${self.amount:.2f}"
    
    def __repr__(self):
        return f"Money({self.amount})"

# %%
m1 = Money(100)
m2 = Money(50)
m1 * 2
# Out:
# Money(200)

# %%
m1 = Money(100)
m2 = Money(50)

print(m1 + m2)   # $150.00
print(m1 - m2)   # $50.00
print(m1 * 2)    # $200.00
# Out:
# $150.00
# $50.00
# $200.00

# %%
class Distance:
    def __init__(self, meters):
        self.meters = meters
    
    def __mul__(self, factor):
        return Distance(self.meters * factor)
    
    def __rmul__(self, factor):
        # Called when: factor * distance
        return Distance(self.meters * factor)
    
    def __str__(self):
        return f"{self.meters}m"

d = Distance(10)

print(d * 5)    # Calls __mul__: 50m
print(5 * d)    # Calls __rmul__: 50m
# Out:
# 50m
# 50m

# %%
str1 = 'siadfhiusheiufhwiuehiufhwiuefh'
len(str1)
# Out:
# 30

# %%
class Playlist:
    def __init__(self, name):
        self.name = name
        self.songs = []
    
    def add_song(self, song):
        self.songs.append(song)
    
    def __len__(self):
        return len(self.songs)

playlist = Playlist("My Favorites")
playlist.add_song("Song 1")
playlist.add_song("Song 2")
playlist.add_song("Song 3")

print(len(playlist))  # 3 (calls __len__)
# Out:
# 3

# %%
class Playlist:
    def __init__(self, name):
        self.name = name
        self.songs = []
    
    def add_song(self, song):
        self.songs.append(song)
    
    def __getitem__(self, index):
        return self.songs[index]
    
    def __len__(self):
        return len(self.songs)

playlist = Playlist("Top Hits")
playlist.add_song("Song A")
playlist.add_song("Song B")
playlist.add_song("Song C")

print(playlist[0])     # "Song A" (calls __getitem__)
print(playlist[-1])    # "Song C"
print(playlist[0:2])   # ['Song A', 'Song B'] (slicing works!)
# Out:
# Song A
# Song C
# ['Song A', 'Song B']

# %% [markdown]
# ### Practice Tasks
#
# 1. Create a class Book with attributes title and pages
#     - Implement \_\_str\_\_ so printing the object gives: <br>
#                 <tab>Book: Atomic Habits (320 pages)
#
# 2. Create a class Vector2D with x and y.
#     - Implement:
#         - \_\_add\_\_ → vector addition
#         - \_\_sub\_\_ → vector subtraction
#         - \_\_mul\_\_ → scalar multiplication
#
# 3. Product Catalog
#     - Create a Product base class with product_id, name, price. Create:
#         - Electronics with warranty_years
#         - Clothing with size and material
#         - Book with author and pages
#     - Each should have a display_details() method showing all relevant information.
#
# 4.  Money Class
#     - Create a Money class with amount and currency. Implement:
#
#         - \_\_str\_\_: "$100.00 USD"
#         - \_\_add\_\_: Can only add same currency
#         - \_\_sub\_\_: Can only subtract same currency
#         - \_\_eq\_\_, \_\_lt\_\_, \_\_gt\_\_: Compare amounts (same currency only)
#         - \_\_mul\_\_: Multiply by a number

# %% [markdown]
# # Exercises
#
# ## 1. Classes and Objects
# - Define a class called `Student` with attributes `name`, `age`, and `grade`.
# - Create an object of the `Student` class and print its attributes.

# %% [markdown]
# ## 2. Instance Variables and Methods
# - Implement the `deposit`, `withdraw`, and `get_balance` methods in the `BankAccount` class.
# - Create a `BankAccount` object and perform deposit and withdrawal operations.

# %% [markdown]
# ## 3. Class Variables and Methods
# - Add a class variable to track the total number of `BankAccount` objects created.
# - Implement a method to return the total number of accounts.

# %% [markdown]
# ## 4. Inheritance
# - Create a parent class `Vehicle` with an attribute `make` and a method `start_engine`.
# - Create a child class `Car` that inherits from `Vehicle` and adds an attribute `model` and a method `drive`.

# %% [markdown]
# ## 5. Abstract Classes and Methods
# - Define an abstract class `Shape` with an abstract method `area`.
# - Create subclasses `Circle` and `Rectangle` that implement the `area` method.

# %% [markdown]
# ## 6. Dunder Methods
# - Implement the `__str__` method in the `Student` class to display student information in a readable format.
# - Implement the `__eq__` method to compare two `Student` objects based on their attributes.
