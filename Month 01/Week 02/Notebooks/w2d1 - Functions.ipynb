# %% [markdown]
# # Srping of Code - Artificial Intelligence
# ## Week 02: Python Fundamentals
# ### Day 01: Functions
# ### Day 02: Exception Handling and File Handling
#
# In this notebook, we will learn about **Functions**, **Exception Handling**, and **File Handling** in Python.

# %% [markdown]
# # Functions in Python
# - A function is a block of reusable code that performs a specific task.
# - Functions help in organizing code, improving readability, and avoiding repetition.
# - Functions can take inputs (parameters) and return outputs (results).
# The syntax for defining a function in Python is as follows:
# ```python
# def function_name(parameters):
#     # Function body
#     # Code to be executed
#     return result  # Optional
# ```

# %%
marks = [10,40,50,45]

avg = (marks[0] + marks[1] + marks[2] + marks[3]) / len(marks)
print("Marks List avg is: ", avg)

# ......
# ......
# ......
# ......
# ......
# ......

salaries = [1000,50000,200000,400000]
avg_salary = (salaries[0] + salaries[1] + salaries[2] + salaries[3]) / len(salaries)
print("Avg Salary: ", avg_salary)

# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......

heights = [5, 4, 6, 4]

avg_height = (heights[0] + heights[1] + heights[2] + heights[3]) / len(heights)
print('Avg Height: ', avg_height)
# Out:
# Marks List avg is:  36.25
# Avg Salary:  162750.0
# Avg Height:  4.75

# %%
def avg(listt):
    summ = 0
    for i in range(len(listt)):
        summ = summ + listt[i]
    
    return summ / len(listt)

# %%
marks = [10,40,50,45]

avg_marks = avg(marks)
print(avg_marks)

# ......
# ......
# ......
# ......
# ......
# ......

salaries = [1000,50000,200000,400000]
avg_salary = avg(salaries)
print(avg_salary)
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......

heights = [5, 4, 6, 4]
avg_heights = avg(heights)
print(avg_heights)
# Out:
# 36.25
# 162750.0
# 4.75

# %%
def greet():
    # statements
    print("Hello Ahmad, Welcome")

# %%
# Out:
# Hello Ahmad, Welcome

# %%
greet
# Out:
# <function __main__.greet()>

# %%
greet()
greet()
greet()
# Out:
# Hello Ahmad, Welcome
# Hello Ahmad, Welcome
# Hello Ahmad, Welcome

# %%
def greet(name): # parameters
    # print("name: " + name)
    print(f"Hello {name}, Welcome")

# %%
name = input('Enter your name:')
greet('Ali')
# Out:
# Hello Ahmad, Welcome

# %% [markdown]
# ## Parameters and Arguments
# - Parameters are placeholders for values that a function can accept.
# - Arguments are the actual values passed to the function when it is called.

# %%
# Function can take input (parameters)
def greet(name): # name is parameter
  print(f"Hello {name}, Welcome to class")

# %%
greet("Ahmad")

# other statements
# Out:
# Hello Ahmad, Welcome to class

# %%
def add(x, y):
    summ = x + y
    return summ

# %%
addd = add(12, 30) # return value
addd
# Out:
# 42

# %%
name1 = greet("Arsalan")
print(name1)
# Out:
# Hello Arsalan, Welcome to class
# None

# %%
num1 = 13
num2 = 14

# Arguments are values passed to the function when calling it
summ = add(num1, num2)
summ
# Out:
# 27

# %%
# functions can return multiple values
def sum_and_prod(x, y, z):
  print(f"x = {x}, y = {y}, z = {z}")
  summ = x + y + z
  prod = x * y * z
  
  return summ, prod

# %%
abc = sum_and_prod(2, 4, 6)
abc
# Out:
# x = 2, y = 4, z = 6
# (12, 48)

# %%
a,b  = (12, 48)

# %%
type(abc)
# Out:
# tuple

# %% [markdown]
# ## Variables and Scope
# Scope refers to the visibility and accessibility of variables in different parts of the code.
# - Variables defined inside a function are local to that function and cannot be accessed outside.
# - Variables defined outside a function are global and can be accessed inside the function.

# %%
# Scope of variables
def func():
  c = 10 # local variable
  print(c)
func()
print(c)  # error, a is local to func()
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 6
#       4   print(c)
#       5 func()
# ----> 6 print(c)  # error, a is local to func()
#
# NameError: name 'c' is not defined

# %%
c = 20  # global variable
print(f"outside func2: {c}")
c = 40

def func2():
    global d
    d = 50
    print(f"inside func2: {d}")

func2()

print(d)
# Out:
# outside func2: 20
# inside func2: 50
# 50

# %%
aaa = 10
print(f"outside my_function: {aaa}")


def my_function():
    aaa = 12
    print(f"inside my_function: {aaa}")

my_function()
# Out:
# outside my_function: 10
# inside my_function: 12

# %% [markdown]
# ## Default, Positional, and Keyword Arguments
# - Default arguments have a default value if no argument is provided.
# - Positional arguments are passed in the order defined in the function.
# - Keyword arguments are passed by explicitly naming them, allowing for flexibility in order.

# %%
def greet(name, age):
    print(f'Hello {name}, Welcome! You are {age} old.')

greet("Alice", 25)
greet(age = 25, name = 'Alice')
# Out:
# Hello Alice, Welcome! You are 25 old.
# Hello Alice, Welcome! You are 25 old.

# %%
# keyword arguments can be used to call functions
# This allows passing arguments in any order
def sum_and_prod(w, x, y, z):
    print(f"w = {w}, x = {x}, y = {y}, z = {z}")
    return w+x+y+z, w*x*y*z

# %%
sum_and_prod(2, 3, 4, 5) # Passing arguments as positional args
# Out:
# w = 2, x = 3, y = 4, z = 5
# (14, 120)

# %%
sum_and_prod(z = 40,w = 10, x = 20, y = 30) # Keyword arguments
# Out:
# w = 10, x = 20, y = 30, z = 40
# (100, 240000)

# %%
sum_and_prod(y=10, x=2, z=3, w=4)
# Out:
# w = 4, x = 2, y = 10, z = 3
# (19, 240)

# %%
def sum_and_prod(w=0, x=0, y=0, z=0):

    print(f"w = {w}, x = {x}, y = {y}, z = {z}")

    return w + x + y + z, w * x * y * z


sum_and_prod(5, z=10)
# Out:
# w = 5, x = 0, y = 0, z = 10
# (15, 0)

# %%
# default arguments
def add(x=0, y=0, z=0):
    print(f"x = {x}, y = {y}, z={z}")
    summ = x + y + z
    return summ

# %%
# passing arguments as positional args
add(12, 10, 30)
# Out:
# x = 12, y = 10, z=30
# 52

# %%
# passign args as keyword args
add(y=10, x=0, z=1)
# Out:
# x = 0, y = 10, z=1
# 11

# %%
add(z=10) # you can skip default arguments
print('hello')
print('world')
# Out:
# x = 0, y = 0, z=10
# hello
# world

# %% [markdown]
# ## Lambda Functions
# - Lambda functions are small anonymous functions defined using the `lambda` keyword.
# - They can take any number of arguments but can only have one expression.
# The syntax for defining a lambda function is as follows:
# ```python
# lambda arguments: expression
# ```

# %%
def square(x):
  # statement 1
  # stateme 2
  return x ** 2

square(3)
# Out:
# 9

# %%
lambda_square = lambda x: x ** 2

# %%
lambda_square(3)
# Out:
# 9

# %% [markdown]
# ## Higher-Order Functions
# - Higher-order functions are functions that can take other functions as arguments or return functions as results.
# - Common higher-order functions in Python include `map()`, `filter()`, and `reduce()`.

# %%
def add_one(x):
  return x + 1

def add_two(x):
  return x + 2

def increment(x, adder): # higher order function
  inc_x = adder(x)
  return inc_x

# %%
increment(12, add_one)
# Out:
# 13

# %%
print(add_one)
# Out:
# <function add_one at 0x000002560ADC3CE0>

# %%
# map() applies a function to all items in an input list and returns 
# a new list with the results.
numbers = list(range(0, 50, 4))
numbers
# Out:
# [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48]

# %%
list(map(lambda x: x+1, numbers))
# Out:
# [1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49]

# %%
def my_filter(x):
  return x > 24

# %%
# filter() creates a list of elements for which a function returns true.
list(filter(lambda x: x > 24, numbers))
# Out:
# [28, 32, 36, 40, 44, 48]

# %%
import random

# %%
# reduce() applies a rolling computation to sequential pairs of 
# values in a list and returns a single value.
import maths_functions

maths_functions.square(3)
# Out:
# 9

# %%
import maths_functions as mfunc
import maths_func

mfunc.pi
# Out:
# 3.143

# %%
from maths_functions import square, pi

square(24)
# Out:
# 576

# %%
pi
# Out:
# 3.141

# %%
from functools import reduce
numbers = list(map(lambda x: x+1, numbers))

reduce(lambda x, y: x+y, numbers)
# Out:
# 325

# %% [markdown]
# #### Some Practice Tasks:
#  - Write a function `calculate_percentage(obtained, total)`
#  - Write a function `calculate_salary(hours, rate)`
#  - Write a function `calculate_bill(price, quantity)` that returns total cost.
#  - Write a function `is_vowel(char)` that returns True or False
#  - Write a function `count_digits(num)` that returns how many digits are in a number.
#  - Write a function `reverse_number(num)`
#  - Write a function `login(username, password)`
#     - Correct → `"Login Successful"`
#     - Else → `"Invalid Credentials"`

# %%
def calculate_percentage(obtained, total):
    percentage = (obtained / total) * 100
    print(f"Percentage: {percentage}%")

# Call
calculate_percentage(44.5, 50)
# Out:
# Percentage: 89.0%

# %%
def calculate_salary(hours, rate):
    salary = hours * rate
    print(f"Salary: {salary}$")

# Call
calculate_salary(40, 15)
# Out:
# Salary: 600$

# %%
def calculate_bill(price, quantity):
    total_bill = price * quantity
    print(f"Total Bill: {total_bill}")

# Call
calculate_bill(19.99, 3)
# Out:
# Total Bill: 59.97

# %%
def is_vowel(char):
    vowels = 'AEIOU'
    if char.upper() in vowels:
        return True
    else:
        return False
# Call
result = is_vowel('i')
print(result)
# Out:
# True

# %%
def count_digits(num):
    str_num = str(num)
    count = len(str_num)
    return count

count_digits(100000000000000)
# Out:
# 15

# %%
def reverse_number(num):
    str_num = str(num)
    reversed_str = str_num[::-1]
    return int(reversed_str)
reverse_number(12345)
# Out:
# 54321

# %%
def login(username, password):
    if username == "admin" and password == "password123":
        print("Login successful!")
    else:
        print("Invalid credentials. Please try again.")
login(username="user", password="password123")
# Out:
# Invalid credentials. Please try again.

# %% [markdown]
# # Errors and Exceptions
# - Errors are issues in the code that prevent it from running correctly.
#   - Syntax errors occur when the code does not follow the correct syntax rules.
#   - Runtime errors occur during the execution of the code.
#   - Logical errors occur when the code runs but produces incorrect results.
# - Exceptions are specific types of errors that can be handled using try-except blocks.

# %%
# Errors and Exceptions example
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

summ = num1 + num2
print(f"Sum: {summ}")

diff = num1 - num2
print(f"Difference: {diff}")

prod = num1 * num2
print(f"Product: {prod}")

quot = num1 / num2 # Careful, problematic, try entering 0 for second number
print(f"Quotient: {quot}")
# Out:
# Sum: 4.0
# Difference: 4.0
# Product: 0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 14
#      11 prod = num1 * num2
#      12 print(f"Product: {prod}")
# ---> 14 quot = num1 / num2 # Careful, problematic, try entering 0 for second number
#      15 print(f"Quotient: {quot}")
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# # Exception Handling
# - Exception handling allows you to manage errors gracefully without crashing the program.
# The syntax for handling exceptions in Python is as follows:
# ```python
# try:
#     # Code that may raise an exception
# except ExceptionType: # Can be multiple except blocks for different exceptions
#     # Code to handle the exception
# finally:
#     # Optional code that runs regardless of whether an exception occurred
# ```

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

summ = num1 + num2
print(f"Sum: {summ}")

diff = num1 - num2
print(f"Difference: {diff}")

prod = num1 * num2
print(f"Product: {prod}")

# quot = num1 / num2  # Since division by zero can raise an exception, we will handle it

try:
    quot = num1 / num2
except ZeroDivisionError:
    quot = None
    print("Error: Division by zero is not allowed.")

print(f"Quotient: {quot}")
print('Last line.')
# Out:
# Sum: 3.0
# Difference: 3.0
# Product: 0.0
# Error: Division by zero is not allowed.
# Quotient: None
# Last line.

# %%
# You can check for multiple exceptions
try:
  quot = num1 / num2
except ZeroDivisionError:
  quot = None
  print("Error: Division by zero is not allowed.")
except Exception as e:
  print(e)
  print("Something went wrong!")
# Out:
# Error: Division by zero is not allowed.

# %%
# Error handling can optionally include else block, which is executed
# when no error occurs in try block
try:
    quot = num1 / num2
except ZeroDivisionError:
    quot = None
    print("Error: Division by zero is not allowed.")
except Exception as e:
    print(e)
else: # this block is executed when no error occurs in try block
  print("No error occurred")
# Out:
# No error occurred

# %%
try:
    marks = int(input("Enter marks: "))
except ValueError:
    print("Invalid input.")
else:
    print("Marks entered successfully:", marks)
# Out:
# Marks entered successfully: 20

# %%
# Error handling can optionally include finally block, which is
# always executed at the end. It doesn't matter whether error occurs
# or not in the try block. Usually used for releasing resources

try:
  file = open("example.txt", "w") # open a file for writing
  file.write("Hello World!\n")
  result = num1 / num2  # error can occur if num2 is zero
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
finally:
    file.close()
    print("File closed. This block is always executed, releasing resources if needed.")
# Out:
# Error: Division by zero is not allowed.
# File closed. This block is always executed, releasing resources if needed.

# %%
try:
    num = int(input("Enter a number: "))
    with open("numbers.txt", "r") as file:
        data = int(file.read())
    print(data / num)
except ValueError:
    print("Error: Invalid number format.")
except FileNotFoundError:
    print("Error: File not found.")
except ZeroDivisionError:
    print("Error: Division by zero.")
# Out:
# Error: File not found.

# %%
balance = 5000

try:
    amount = int(input("Enter withdrawal amount: "))

    if amount > balance:
        raise ValueError("Insufficient balance")

    balance -= amount
    print("Withdrawal successful. Balance:", balance)

except ValueError as e:
    print("Error:", e)
# Out:
# Error: Insufficient balance

# %% [markdown]
# # Working with Files
# - Python allows you to read from and write to files on your system.
# - Common file operations include opening, reading, writing, and closing files.
# - The syntax for file handling in Python is as follows:
# ```python
# file = open('filename', 'mode')  # Open a file
# # Perform file operations (read, write, etc.)
# file.close()  # Close the file
# ```

# %%
print('Ahmad\nHome')
# Out:
# Ahmad
# Home

# %%
"D:\\nvttc-ai\\Month 01\\Week 02\\Notebooks\\functions.txt"
'D:\\nvttc-ai\\Month 01\\Week 02\\Notebooks\\example.txt'
# Out:
# 'D:\\nvttc-ai\\Month 01\\Week 02\\Notebooks\\functions.txt'

# %%
# Absolute Path
file = open("D:\\nvttc-ai\\Month 01\\Week 02\\Notebooks\\example.txt", 'r')
file
file.close()

# %%
# Relative Path
file = open("functions.txt", mode='r')
file
# Out:
# <_io.TextIOWrapper name='functions.txt' mode='r' encoding='cp1252'>

# %%
file.name
# Out:
# 'functions.txt'

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
file.read()
# Out:
# 'This is a line\nThis is second line\nTwinkle twinkle little stars\nhow i wonder what you are\nstatements\nTwinkle twinkle little stars\nhow i wonder what you are\nstatements\n'

# %%
file = open('functions.txt', 'r')
file
# Out:
# <_io.TextIOWrapper name='functions.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# ## Reading from Files
# - read()
# - readline()
# - readlines()

# %%
file.read()
# Out:
# 'This is a line\nThis is second line\nTwinkle twinkle little stars\nhow i wonder what you are\nstatements\nTwinkle twinkle little stars\nhow i wonder what you are\nstatements\n'

# %%
file.read() # since cursor is at the end of the file
# Out:
# ''

# %%
# To move cursor to the starting position
file.seek(0)
# Out:
# 0

# %%
# readline
file.readline()
# Out:
# 'This is a line\n'

# %%
# To know the cursor position
file.tell()
# Out:
# 16

# %%
file.readline()
# Out:
# 'This is second line\n'

# %%
file.readline()
# Out:
# 'Twinkle twinkle little stars\n'

# %%
file.readline()
# Out:
# 'how i wonder what you are\n'

# %%
file.readline()
# Out:
# 'statements\n'

# %%
file.readline()
# Out:
# 'Twinkle twinkle little stars\n'

# %%
file.readline()
# Out:
# 'how i wonder what you are\n'

# %%
file.readline() # reached end
# Out:
# 'statements\n'

# %%
file.readline() # reached end
# Out:
# ''

# %%
# move cursor to starting position again
file.seek(0)
# Out:
# 0

# %%
# readlines
lines = file.readlines()

# %%
lines[2]
# Out:
# 'Twinkle twinkle little stars\n'

# %%
file.close()

# %% [markdown]
# ## Writing to Files
# - write("text")
# - writelines(["list", "of", "texts"])

# %%
f = open('functions.txt', mode='w')
f.write("This is a line\n")
f.write("This is second line")
f.close() # file will be updated after it is closed

# %%
poem = [
  "Twinkle twinkle little stars\n",
  "how i wonder what you are\n",
  "statements\n"
]

f = open(f'functions.txt', mode='a')
f.writelines(poem)
f.close()

# %% [markdown]
# ## Context Managers
# - Context managers provide a way to manage resources, such as file handling, ensuring that they are properly acquired and released.
# - In Python, the `with` statement is used to create a context manager.
#
# The syntax for using a context manager is as follows:
# ```python
# with open('filename', 'mode') as file:
#     # Perform file operations (read, write, etc.)
#     # The file is automatically closed when the block is exited
# ```

# %%
with open('functions.txt', mode='r') as f:
  print(f.readlines())
# Out:
# ['This is a line\n', 'This is second lineTwinkle twinkle little stars\n', 'how i wonder what you are\n', 'statements\n', 'Asad']

# %%
with open("functions.txt", mode="a") as f:
    f.write("Asad")

print("File closed")
f.closed
# Out:
# File closed
# True

# %% [markdown]
# #### Some Real World Examples

# %% [markdown]
# #### Feedback Collection System

# %%
feedback = input("Enter feedback: ")

with open("feedback.txt", mode="a") as file:
    file.write(feedback + "\n")

print("Thanks for your feedback!")
# Out:
# Thanks for your feedback!

# %%
with open("feedback.txt", "r") as file:
    print("Total feedbacks:", len(file.readlines()))
# Out:
# Total feedbacks: 3

# %% [markdown]
# ##### To-Do List App

# %%
task = input("Enter new task: ")

with open("todo.txt", "a") as file:
    file.write(task + "\n")

# %% [markdown]
# (0,'Ahmad')

# %%
a = '    hello    '
a.strip()
# Out:
# 'hello'

# %%
with open("results.txt", "r") as file:
    for i, task in enumerate(file, start=1):
        print(i, task.strip())
# Out:
# 1 ahmad = 93
# 2 sara = 46
# 3 ali = 94

# %% [markdown]
# #### Exam Result Checker

# %%
search = input("Enter student name: ")

with open("results.txt", "r") as file:
    for line in file:
        name, marks = line.split(" = ") 
        if name == search:
            print("Marks:", marks)
            break
    else:
        print("Result not found")
# Out:
# Marks: 93

# %% [markdown]
# #### Mobile Contact Book

# %%
name = input("Contact name: ")
number = input("Phone number: ")

with open("contacts.txt", "a") as file:
    file.write(name + "," + number + "\n")

# %%
with open("contacts.txt", "r") as file:
    for line in file:
        name, number = line.strip().split(",")
        print(name, "=>", number)

# %% [markdown]
# #### Login + Password Check

# %%
username = input("Username: ")
password = input("Password: ")

with open("users.txt", "r") as file:
    for line in file:
        u, p = line.strip().split(",")

        if u == username and p == password:
            print("Login Successful")
            break
    else:
        print("Invalid Credentials")
# Out:
# Invalid Credentials

# %% [markdown]
# #### Some Practice Tasks

# %% [markdown]
# 1. Create a file called `notes.txt`
#     - Write any 5 lines into it
#     - Read and print all lines
# 2. Daily Log
#     - Take user input
#     - Append it to daily_log.txt
# 3. Search in File
#     - Ask for a word
#     - Check if it exists in a file
# 4. Result Management
#     - Store name=marks
#     - Search and display grade
